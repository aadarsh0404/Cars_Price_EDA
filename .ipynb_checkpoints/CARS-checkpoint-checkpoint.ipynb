# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Automobile_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2504eff349c9> in <module>
# ----> 1 data = pd.read_csv("Automobile_data.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
cars=data.dropna().fillna('0')

# %%
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
cars.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178515 -0.035823
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap="coolwarm")

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
columns = cars.columns
df_slow = cars.copy()
#df_slow['Num'] = poke['#']
to_rename = columns[[]]
for col in to_rename:
  if '.' in col:
      cola = col.replace('. ', '_')
  else:
      cola = col.replace(' ', '_')
  df_slow[cola] = cars[col]
df_slow = df_slow.drop(columns=columns[[]])
print(df_slow.columns)
print(cars.shape)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')
# (205, 26)

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
cars.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
cars.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
columns = cars.columns
df_slow = cars.copy()
df_slow['Num'] = cars['#']
to_rename = columns[[1,]]
for col in to_rename:
  if '.' in col:
      cola = col.replace('. ', '_')
  else:
      cola = col.replace(' ', '_')
  df_slow[cola] = cars[col]
df_slow = df_slow.drop(columns=columns[[0,2,3,8,9]])
print(df_slow.columns)
print(cars.shape)

# %%
columns=cars.columns
print (columns)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
num_feat=[feature for feature in columns if data[feature].dtype !=  'O']
print(num_feat)
print("NO of numerical features is ",len(num_feat))
# Out:
# ['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg']
# NO of numerical features is  10

# %%
cat_feat=[feature for feature in columns if data[feature].dtype ==  'O']
print(cat_feat)
print("NO of Categorical features is ",len(cat_feat))
# Out:
# ['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']
# NO of Categorical features is  16

# %%
for col in cat_feat:
   print(col)
   print(cars[col].value_counts())
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 104     6
# 128     6
# 168     5
# 94      5
# 65      5
# 95      5
# 103     5
# 102     5
# 74      5
# 85      5
# 122     4
# 106     4
# 148     4
# 118     4
# 93      4
# 137     3
# 83      3
# 115     3
# 101     3
# 125     3
# 154     3
# 119     2
# 108     2
# 188     2
# 197     2
# 81      2
# 164     2
# 194     2
# 110     2
# 153     2
# 113     2
# 129     2
# 145     2
# 89      2
# 158     2
# 87      2
# 192     2
# 77      1
# 98      1
# 256     1
# 121     1
# 107     1
# 78      1
# 231     1
# 186     1
# 90      1
# 142     1
# Name: normalized-losses, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              7
# ...

# %%
for col in num_feat:
   print(col)
   cars[col].replace('?', cars[col].mean())
# Out:
# symboling
# wheel-base
# length
# width
# height
# curb-weight
# engine-size
# compression-ratio
# city-mpg
# highway-mpg

# %%
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
new=cars.copy()
new['price']=pd.to_numeric(new['price'],errors='coerce')

# %%
new.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
col=[feature for feature in new if new[feature].dtype !=  'object']

# %%
new_cars = new[col].copy()
new_cars['price'].dtype
# Out:
# dtype('float64')

# %%
sns.pairplot(new_cars,height=1.5)
# Out:
# C:\Users\shash\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\shash\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
new_cars.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
# price              -0.082391    0.584642  0.690628  0.751265  0.135486
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# ...

# %%
sns.scatterplot(new_cars['highway-mpg'],new_cars['city-mpg'])

# %%
plt.subplot(131)
sns.boxplot(new_cars['highway-mpg'])
plt.subplot(132)
sns.boxplot(new_cars['city-mpg'])
plt.subplot(133)
sns.boxplot(new_cars['wheel-base'])

# %%
plt.subplot(131)
sns.boxplot(new_cars['length'])
plt.subplot(132)
sns.boxplot(new_cars['curb-weight'])
plt.subplot(133)
sns.boxplot(new_cars['engine-size'])

# %%
new_cars = new_cars.dropna()

# %%
def interpolation(X):
    Y = ((27)*(X-1))+68
    return Y
def revinter(Y):
    X = ((Y-68)/27)+1
    return X

# %%
values = []
c = 0
ct = 0
for i in new_cars['price'].values:
    ct = ct + 1
print(ct)
for i in range(0,ct):
    values.append(False)
    c = c + 1
for col in new_cars.columns:
    c = 0
    M = max(new_cars[col])
    m, s = np.mean(new_cars[col]), np.std(new_cars[col])
    L, H = m-1.6667*s, m+1.6667*s
    #plt.subplots()
    print('range sd',col,L,'to ',H)
    #sns.distplot(new_cars[col])
    for i in new_cars[col].values:
        if(i<L or i>H):
            values[c]= True
            c = c + 1
        else:
            c = c + 1
ct = 0
for i in values:
    ct = ct + 1
new_cars['outlier_sd'] = values
# Out:
# 201
# range sd symboling -1.2453730915051762 to  2.926965131306171
# range sd wheel-base 88.71138608819659 to  108.88264376254982
# range sd length 153.71477748253747 to  194.68721256721417
# range sd width 62.39525691640142 to  69.38285253633484
# range sd height 49.697042844111024 to  57.83629048922241
# range sd curb-weight 1695.6356092156693 to  3415.6977241176637
# range sd engine-size 57.80198169763868 to  195.94926208345584
# range sd compression-ratio 3.505827990134157 to  16.822729223796195
# range sd city-mpg 14.500186927273143 to  35.85802202795074
# range sd highway-mpg 19.356047743967657 to  42.017086584390555
# range sd price -5.2563404471220565 to  26419.515046914785
# range sd outlier_iqr 0.0 to  0.0

# %%
new_cars.drop(['outlier_iqr'],axis=1)
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# 5            2        99.8   177.3   66.3    53.1         2507          136
# 6            1       105.8   192.7   71.4    55.7         2844          136
# 7            1       105.8   192.7   71.4    55.7         2954          136
# 8            1       105.8   192.7   71.4    55.9         3086          131
# 10           2       101.2   176.8   64.8    54.3         2395          108
# 11           0       101.2   176.8   64.8    54.3         2395          108
# ...

# %%
new_cars = new_cars.dropna()
values = []
ct = 0
for i in new_cars['price'].values:
    ct = ct + 1
print(ct)
for i in range(0,ct):
    values.append(False)
for col in new_cars.columns:
    c = 0
    q3 = new_cars[col].quantile(0.75)
    q1 = new_cars[col].quantile(0.25)
    iqr = q3 - q1
    maximum = q3 + 1.5*iqr
    minimum = q1 - 1.5*iqr
    print('range iqr',col,minimum,'to ',maximum)
    for i in new_cars[col].values:
        if(i>maximum or i<minimum):
            values[c] = True
            c = c + 1
        else:
            c = c + 1
    #plt.subplots()
    #sns.distplot(new_cars[col])
ct = 0
for i in values:
    if(i==True):
        ct = ct + 1
print(ct)
# Out:
# 201
# range iqr symboling -3.0 to  5.0
# range iqr wheel-base 82.64999999999999 to  114.25000000000001
# range iqr length 141.75000000000003 to  208.54999999999998
# range iqr width 60.349999999999994 to  70.35
# range iqr height 46.75 to  60.75
# range iqr curb-weight 1033.5 to  4061.5
# range iqr engine-size 33.5 to  205.5
# range iqr compression-ratio 7.399999999999999 to  10.600000000000001
# range iqr city-mpg 2.5 to  46.5
# range iqr highway-mpg 11.5 to  47.5
# range iqr price -5312.5 to  29587.5
# range iqr outlier_iqr 0.0 to  0.0
# range iqr outlier_sd -1.5 to  2.5
# 44

# %%
new_cars
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# 5            2        99.8   177.3   66.3    53.1         2507          136
# 6            1       105.8   192.7   71.4    55.7         2844          136
# 7            1       105.8   192.7   71.4    55.7         2954          136
# 8            1       105.8   192.7   71.4    55.9         3086          131
# 10           2       101.2   176.8   64.8    54.3         2395          108
# 11           0       101.2   176.8   64.8    54.3         2395          108
# ...

# %%
c = 0
for val in new_cars['outlier_iqr'].values:
    if(val == False):
        c = c + 1
print(c)
# Out:
# 205

# %%
outlier_reason = []
ct = 0
for i in new_cars['price'].values:
    ct = ct + 1
#print(ct)
for i in range(0,ct):
    outlier_reason.append('NA')
for col in new_cars.columns:
    c = 0
    q3 = new_cars[col].quantile(0.75)
    q1 = new_cars[col].quantile(0.25)
    iqr = q3 - q1
    maximum = q3 + 1.5*iqr
    minimum = q1 - 1.5*iqr
    #print('range iqr',col,minimum,'to ',maximum)
    for i in new_cars[col].values:
        if(i>maximum or i<minimum):
            outlier_reason[c] = 'Due to '+col+ ' in iqr'
            c = c + 1
        else:
            c = c + 1
outlier_reason
# Out:
# ['NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'Due to width in iqr',
#  'Due to width in iqr',
#  'Due to width in iqr',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'Due to price in iqr',
#  'Due to price in iqr',
#  'Due to price in iqr',
#  'Due to highway-mpg in iqr',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'Due to compression-ratio in iqr',
#  'Due to highway-mpg in iqr',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'Due to price in iqr',
#  'Due to price in iqr',
#  'Due to price in iqr',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'Due to compression-ratio in iqr',
#  'NA',
#  'NA',
#  'Due to compression-ratio in iqr',
#  'Due to compression-ratio in iqr',
#  'Due to compression-ratio in iqr',
#  'Due to compression-ratio in iqr',
# ...

# %%
for col in new_cars.columns:
    c = 0
    M = max(new_cars[col])
    m, s = np.mean(new_cars[col]), np.std(new_cars[col])
    L, H = m-1.6667*s, m+1.6667*s
    #plt.subplots()
    #print('range sd',col,L,'to ',H)
    #sns.distplot(new_cars[col])
    for i in new_cars[col].values:
        if(i<L or i>H):
            if('iqr' in outlier_reason[c]):
                outlier_reason[c] = 'Due to '+col+ ' in iqr and sd'
            else:
                outlier_reason[c] = 'Due to '+col+ ' in sd'
            c = c + 1
        else:
            c = c + 1
new_cars['outlier reason'] = outlier_reason

# %%
new_cars
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# 5            2        99.8   177.3   66.3    53.1         2507          136
# 6            1       105.8   192.7   71.4    55.7         2844          136
# 7            1       105.8   192.7   71.4    55.7         2954          136
# 8            1       105.8   192.7   71.4    55.9         3086          131
# 10           2       101.2   176.8   64.8    54.3         2395          108
# 11           0       101.2   176.8   64.8    54.3         2395          108
# ...

# %%
new_cars.count()
# Out:
# symboling            201
# wheel-base           201
# length               201
# width                201
# height               201
# curb-weight          201
# engine-size          201
# compression-ratio    201
# city-mpg             201
# highway-mpg          201
# price                201
# outlier_iqr          201
# outlier_sd           201
# outlier reason       201
# dtype: int64

# %%
outlier = {}
num_col = new_cars.columns
for j in num_col:
    outlier[j] = 0
for i in new_cars['outlier reason'].values:
    for j in num_col:
        if(j in i):
            outlier[j] = outlier[j] + 1
print(outlier)
# Out:
# {'symboling': 18, 'wheel-base': 4, 'length': 4, 'width': 4, 'height': 15, 'curb-weight': 0, 'engine-size': 0, 'compression-ratio': 12, 'city-mpg': 6, 'highway-mpg': 9, 'price': 16, 'outlier_iqr': 0, 'outlier_sd': 0, 'outlier reason': 0}
